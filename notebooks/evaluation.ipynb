# %% [markdown]
# ### Prerequisites

# %%
import os
import sys
from pathlib import Path

# gets project root, which is 1 level above notebooks/, where
# this ipynb lives
project_root = Path.cwd().resolve().parent

# add project_root to the front of the module search paths
# (it's not automatic)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

os.chdir(project_root)

# %%
from domain.settings import settings

settings.gemini_api_key

# %% [markdown]
# ### Define source transcript

# %%
source_transcript = """\
The patient appeared somewhat reserved and soft-spoken initially but became more 
communicative as the session progressed. We spent the first half of the hour 
running through rapid category-switch drills and phonemic fluency exercises, 
where she showed a brief delay when switching between semantic groups. She noted
that she felt highly overwhelmed when trying to follow fast-paced group
conversations at a family dinner last Thursday. For next time, I directed her to
practice the timed category worksheets for ten minutes daily and to try using a
five-second pause strategy before responding during stressful conversations.
"""

# %% [markdown]
# ### Define ClinicalSummary

# %%
from schemas.clinical_summary import ClinicalSummary

summary = ClinicalSummary(
    patient_mood="somewhat reserved",
    exercises_completed=[
        "rapid category-switch drills",
        "phonemic fluency exercises",
    ],
    symptoms_mentioned=["feeling overwhelmed in fast-paced group conversations"],
    next_steps="practice timed category worksheets for 10 minutes daily and try using a 5-second pause strategy before responding during stressful conversations",
)

# %% [markdown]
# ### Setup system prompt

# %%
from prompts.evaluation import system_prompt

system_prompt

# %% [markdown]
# ### Run evaluation of generated summary

# %% [markdown]
# #### Select client (run one of them)

# %%
# from clients.base import EvaluationEngine
# from clients.gemini import GeminiClient

# client = GeminiClient(settings.gemini_api_key)
# evaluation_engine = EvaluationEngine(client, settings.gemini_model_for_extraction)

# %%
# from clients.base import EvaluationEngine
# from clients.openai import OpenAIClient

# client = OpenAIClient(settings.openai_api_key)
# evaluation_engine = EvaluationEngine(client, settings.openai_model_for_evaluation)

# %%
# from clients.base import EvaluationEngine
# from clients.deepseek import DeepSeekClient

# client = DeepSeekClient(settings.deepseek_api_key, settings.deepseek_base_url)
# evaluation_engine = EvaluationEngine(client, settings.deepseek_model_for_evaluation)

# %%
# from clients.base import EvaluationEngine
# from clients.ollama import OllamaClient

# client = OllamaClient(ollama_host='localhost:11434')
# evaluation_engine = EvaluationEngine(client, settings.llama_model_for_evaluation)

# %%
# Depends on .env
from domain.container import DependencyContainer

container = DependencyContainer()
evaluation_engine = container.eval_engine

evaluation_engine.model

# %% [markdown]
# #### Do the evaluation

# %%
result = await evaluation_engine.evaluate(
    summary,
    source_transcript,
    'your-sess-id'
)

result
